# %% [markdown]
# <a href="https://colab.research.google.com/github/yodaboop/Prompt-Engineer/blob/main/Prompt_Chaining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Code generation with prompt chaining using Gemini
#
# **Prompt:**
#
# Build a bot that using script from gemini api key and can work on prompt chaining:
#
# Prompt 1: Generate a user persona for a new app aimed at college students.
#
# Prompt 2: Based on this persona, create a list of top 5 features the app should have.
#
# Prompt 3: Write a pitch deck slide describing one of those features

# %%
import google.generativeai as genai
import os

# --- 1. Configuration ---
# IMPORTANT: Store your API key securely.
# Option A: For Google Colab, use the "Secrets" (key icon) tab
from google.colab import userdata
GEMINI_API_KEY = userdata.get('GEMINI_API_KEY')

# Option B: For local development, use environment variables
# (Run `export GEMINI_API_KEY='Your_Key_Here'` in your terminal first)
# GEMINI_API_KEY = os.environ.get("GEMINI_API_KEY")

if not GEMINI_API_KEY:
    raise ValueError("Gemini API key not found. Please set the environment variable or Colab secret.")

genai.configure(api_key=GEMINI_API_KEY)

# Initialize the model
# You can use 'gemini-2.5-flash' for speed or 'gemini-2.5-pro' for complex tasks
model = genai.GenerativeModel('gemini-2.5-flash')

print("--- 🤖 Bot Initialized ---")
print("Starting prompt chain...\n")

try:
    # --- 2. Prompt 1: Generate Persona ---
    print("--- ➡️ STEP 1: Generating Persona ---")
    prompt_1 = "Generate a user persona for a new app aimed at college students. Include name, major, goals, and frustrations."

    response_1 = model.generate_content(prompt_1)
    persona = response_1.text

    print("✅ Persona Created:\n", persona)
    print("\n" + "="*30 + "\n")

    # --- 3. Prompt 2: Generate Features (using Persona) ---
    print("--- ➡️ STEP 2: Generating Features ---")

    # Here is the chain: we insert the text from response_1 into prompt_2
    prompt_2 = f"""
    Based on this user persona:
    {persona}

    Create a list of the top 5 most essential features this app should have to solve their frustrations and meet their goals.
    """

    response_2 = model.generate_content(prompt_2)
    features = response_2.text

    print("✅ Features Generated:\n", features)
    print("\n" + "="*30 + "\n")

    # --- 4. Prompt 3: Write Pitch Deck Slide (using Features) ---
    print("--- ➡️ STEP 3: Writing Pitch Deck Slide ---")

    # The chain continues: we insert the text from response_2 into prompt_3
    prompt_3 = f"""
    You are a marketing expert. Your task is to write a single, persuasive pitch deck slide.

    Use this list of features as your source:
    {features}

    Pick the *single most compelling* feature from the list and write the slide content for it. The slide should have:
    1. A catchy Headline (e.g., "The Smartest Study Tool on Campus")
    2. 2-3 bullet points describing the feature and its key benefit.
    3. A clear concluding statement of value.
    """

    response_3 = model.generate_content(prompt_3)
    slide_content = response_3.text

    print("✅ Pitch Deck Slide Written:\n", slide_content)
    print("\n" + "="*30 + "\n")

    print("--- ✨ Prompt Chain Complete! ---")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# --- 🤖 Bot Initialized ---
# Starting prompt chain...
#
# --- ➡️ STEP 1: Generating Persona ---
# ✅ Persona Created:
#  Here's a user persona for a new app aimed at college students:
#
# ---
#
# ## User Persona: Alex Chen
#
# **"The Ambitious Overachiever"**
#
# ---
#
# *   **Name:** Alex Chen
# *   **Age:** 20
# *   **Year:** Junior
# *   **Major:** Computer Science (with a minor in Cognitive Science)
# *   **University:** State University (Large, public institution)
#
# ---
#
# ### About Alex
#
# Alex is a driven and intelligent student from a suburban background, known for being tech-savvy and highly organized – *or at least, trying to be*. They came to college with big dreams of making an impact in the tech world. Alex is academically strong, loves problem-solving, and enjoys collaborating on projects. They are reasonably social, having a core group of friends, but often feel torn between their academic responsibilities, club commitments (President of the university's AI & Robotics Club), and a desire to maintain a healthy social life and personal well-being. Alex lives on campus in a shared apartment.
#
# **Quote:** *"There's so much I want to do and achieve, but sometimes I feel like I'm constantly drowning in deadlines and opportunities. I just need a clearer picture of everything."*
#
# ---
#
# ### Goals
#
# 1.  **Academic Excellence:** Maintain a high GPA, excel in challenging CS courses, and secure a strong internship for the upcoming summer.
# 2.  **Career Development:** Build a robust portfolio of projects, network with industry professionals, and stay updated on tech trends.
# 3.  **Effective Time Management:** Balance demanding coursework, club leadership, personal projects, and social activities without feeling constantly overwhelmed.
# 4.  **Personal Well-being:** Get enough sleep, eat healthily, make time for exercise, and reduce overall stress and anxiety.
# 5.  **Stay Connected & Informed:** Keep up with campus events, workshops, and social gatherings without constant FOMO (Fear Of Missing Out).
# 6.  **Optimize Learning:** Find efficient ways to study, retain information, and collaborate with peers on group assignments.
#
# ---
#
# ### Frustrations
#
# 1.  **Information Overload:** Juggling multiple platforms for assignments (LMS, Piazza), club communications (Discord, email), personal calendar (Google Calendar), and social plans (GroupMe, Instagram). It's hard to get a unified view of their day/week.
# 2.  **"Death by a Thousand Emails":** Their university email inbox is a constant flood of announcements, deadlines, club updates, and spam, making it difficult to prioritize important messages.
# 3.  **Procrastination & Deadlines:** Despite being organized, the sheer volume of tasks sometimes leads to paralysis by analysis, resulting in last-minute rushes and stress before deadlines.
# 4.  **Missed Opportunities:** Hearing about cool workshops, career fairs, or social events *after* they've already happened because the information was buried in an email or a post they didn't see.
# 5.  **Difficulty Prioritizing:** With multiple projects and commitments, it's hard to objectively decide what needs immediate attention versus what can wait, leading to inefficient work habits.
# 6.  **Lack of Integrated Planning:** Their current tools (physical planner, Google Calendar, Notion for notes, Todoist for tasks) don't "talk" to each other, requiring manual entry and cross-referencing.
# 7.  **Maintaining Work-Life Balance:** The constant pressure to succeed often means sacrificing sleep or social plans, leading to burnout. They want to be more intentional about scheduling downtime.
# 8.  **Finding Study Buddies/Collaborators:** While active in clubs, sometimes it's hard to quickly find other students in their specific classes who want to work together on challenging assignments or prep for exams.
#
# ---
#
# ### Technology & Habits
#
# *   **Devices:** iPhone 14 Pro, MacBook Pro, Apple Watch.
# *   **Apps:** Heavily uses Google Calendar, Notion, Todoist, Discord, Spotify, Slack, Instagram, LinkedIn, various university-specific apps (LMS, bus tracker).
# *   **Communication:** Prefers quick texts and DMs for social, but relies on email for formal university communications (though struggles with its volume).
# *   **Learning Style:** Visual learner, benefits from structured schedules and checklists.
# *   **Screen Time:** Averages 6-8 hours daily on their phone, not including laptop use.
#
# ---
#
# ### What Alex Hopes for in a New App
#
# Alex is looking for a comprehensive, intelligent platform that can act as a central hub for their entire college life. They want an app that:
# *   Integrates calendars, assignments, and club events from various sources.
# *   Provides smart reminders and proactive suggestions for prioritizing tasks.
# *   Helps them discover relevant opportunities (internships, workshops) tailored to their major and interests.
# *   Facilitates easy connection and collaboration with peers for academic purposes.
# *   Offers features to track well-being and encourage breaks.
# *   Is intuitive, visually clean, and reduces their overall mental load.
#
# ==============================
#
# --- ➡️ STEP 2: Generating Features ---
# ✅ Features Generated:
#  Based on Alex Chen's persona, the top 5 most essential features for this new app should directly address their core frustrations of information overload, time management difficulties, missed opportunities, and burnout, while helping them achieve academic, career, and personal well-being goals.
#
# Here are the top 5 essential features:
#
# 1.  **Intelligent Unified Dashboard & Inbox:**
#     *   **Solves:** Information Overload, "Death by a Thousand Emails," Lack of Integrated Planning.
#     *   **Meets:** Effective Time Management, Stay Connected & Informed.
#     *   **Description:** A single, centralized hub that aggregates all relevant information: assignments from LMS (Canvas/Blackboard), club communications (Discord, Slack, emails), personal calendar events (Google Calendar sync), and social plans (GroupMe/text sync). This dashboard would intelligently filter and prioritize notifications, showing Alex a consolidated, clear view of their day, week, and upcoming deadlines, cutting through the email clutter by surfacing important academic and club alerts.
#
# 2.  **AI-Powered Task & Deadline Prioritization:**
#     *   **Solves:** Procrastination & Deadlines, Difficulty Prioritizing.
#     *   **Meets:** Academic Excellence, Effective Time Management.
#     *   **Description:** An intelligent system that not only lists tasks from all integrated sources but also suggests priorities based on deadlines, estimated effort (user-inputted or AI-learned), course difficulty, and Alex's current schedule. It would provide proactive reminders, allow for breaking down large projects into smaller steps, and offer "focus mode" timers (e.g., Pomodoro) to combat procrastination and maintain momentum.
#
# 3.  **Personalized Opportunity & Event Discovery:**
#     *   **Solves:** Missed Opportunities.
#     *   **Meets:** Career Development, Stay Connected & Informed.
#     *   **Description:** A smart feed that learns Alex's major, minor, club affiliations, and interests to proactively recommend relevant workshops, career fairs, internships, hackathons, guest lectures, and social campus events. It would pull information from university event calendars, career services, and industry news, ensuring Alex doesn't miss out on valuable academic, career, or social opportunities that were previously buried in emails or obscure platforms.
#
# 4.  **Integrated Study & Collaboration Network:**
#     *   **Solves:** Finding Study Buddies/Collaborators.
#     *   **Meets:** Optimize Learning, Academic Excellence.
#     *   **Description:** A feature allowing Alex to easily connect with other students in their specific courses or clubs. This would facilitate forming study groups, finding project collaborators, and asking/answering questions about assignments. It could include private and public chat channels for classes, shared document editing capabilities, and a simple "find a study buddy for [Course Name]" function.
#
# 5.  **Work-Life Balance & Well-being Toolkit:**
#     *   **Solves:** Maintaining Work-Life Balance, overall stress/anxiety.
#     *   **Meets:** Personal Well-being, Effective Time Management.
#     *   **Description:** Tools within the app to help Alex intentionally schedule downtime and track well-being. This could include a "smart break scheduler" that suggests short breaks between tasks, a gentle reminder to log off or prepare for sleep based on their calendar, simple habit tracking for exercise/meals, and potentially integration with sleep/fitness trackers (Apple Watch) to provide a holistic view and encourage healthier habits.
#
# ==============================
#
# --- ➡️ STEP 3: Writing Pitch Deck Slide ---
# ✅ Pitch Deck Slide Written:
#  Here is the persuasive pitch deck slide for the most compelling feature:
#
# ---
#
# ## Conquer Overwhelm: Your AI-Powered Priority Engine
#
# *   **Intelligent Task Prioritization:** Eliminate guesswork. Our AI sifts through *all* your commitments – from assignments to club meetings – and intelligently suggests your top priorities based on deadlines, estimated effort, and *your* unique schedule.
# *   **Proactive Focus & Execution:** Say goodbye to procrastination. Get timely reminders, break down large projects into manageable steps, and activate built-in "Focus Modes" (like Pomodoro) to maintain momentum and achieve deep work.
#
# **Stop juggling tasks and start *succeeding*. Our AI ensures you focus on what truly matters, transforming overwhelm into accomplishment and freeing you to thrive in every aspect of your life.**
#
# ---
#
# ==============================
#
# --- ✨ Prompt Chain Complete! ---
